# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairanga-Putta/Projects/blob/main/Face_Detection/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing required Libraries**

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import requests
from io import BytesIO

# %% [markdown]
# **Giving Image Address as Input**

# %%
img_address = input()
if img_address[:4]=="http":
  response = requests.get(url)
  img = Image.open(BytesIO(response.content))
  img = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
else:
  img=cv2.imread(img_address)
# Out:
# https://media.glamour.com/photos/569580808fa134644ec25ffd/16:9/w_1280,c_limit/entertainment-2015-09-how-i-met-your-mother-season-1-main.jpg

# %% [markdown]
# **Converting Image for Compatability and Visualization**

# %%
plt.plot()
plt.title('RGB2BGR Image')
plt.imshow(img)
plt.axis('off')
print(img.shape)
# Out:
# (720, 1280, 3)

# %% [markdown]
# **Reducing to Grayscale to focus on Structural Pattern**

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print('Image shape after Gray scaling :',gray_img.shape)
plt.plot()
plt.title('IMage after GrayScaling')
plt.imshow(gray_img)
plt.axis('off')
# Out:
# Image shape after Gray scaling : (720, 1280)
# (-0.5, 1279.5, 719.5, -0.5)

# %% [markdown]
# **Detecting and Plotting the Faces**

# %%
face_classifier=cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
face=face_classifier.detectMultiScale(gray_img,scaleFactor=1.1,minNeighbors=5,minSize=(20,20))
for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),4)
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5,5))
plt.title("Face Detection")
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 719.5, -0.5)
